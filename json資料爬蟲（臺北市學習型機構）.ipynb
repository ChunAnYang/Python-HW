# %%
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import requests
import json

r = requests.get("https://data.taipei/api/getDatasetInfo/downloadResource?id=ac589468-529b-4636-a9b2-ab57ae41cbcb&rid=24c9f8fe-88db-4a6e-895c-498fbc94df94")

#data = json.loads(r.text)
#print(r.status_code)

if r.status_code == requests.codes.ok:
    print(r.text)
    #print(data["result"])
# Out:
# [{"o_tlc_agency_name":"臺北市立大學附設實驗國民小學","o_tlc_agency_category":"1","o_tlc_agency_categorychild":"小學","o_tlc_agency_purpose":"培育文采有品 領袖群倫的附小兒 (一)倡導前瞻的領導理念，落實推動教育政策。 (二)建立專業的領導團隊，發揮組織整體效能。  (三)重視系統的領導歷程，提升教育全面品質。  (四)展現卓越的領導績效，創造教育永續發展。","o_tlc_agency_service":"教育7~12歲幼童","o_tlc_agency_region":"11","o_tlc_agency_opentime":"平日：0730～1700假日：0800～1600","o_tlc_agency_address":"臺北市中正區公園路29號","o_tlc_agency_phone":"(02)2311-0395","o_tlc_agency_fax":"(02)2331-0319","o_tlc_agency_email":"http://web.estmue.tp.edu.tw/php/email.php/%E6%96%B9%E6%85%A7%E7%90%B4","o_tlc_agency_admincategory":"臺北市政府教育局","o_tlc_agency_img_front":"https://www.lct.tp.edu.tw/ezfiles/1/1001/agency/1/agency_507_6894974_56101.jpg","o_tlc_agency_img_inner":"https://www.lct.tp.edu.tw/ezfiles/1/1001/agency/1/agency_507_4406609_56101.jpg","o_tlc_agency_link":"http://esut.tp.edu.tw/"},{"o_tlc_agency_name":"臺北市中正區東門國民小學","o_tlc_agency_category":"1","o_tlc_agency_categorychild":"小學","o_tlc_agency_purpose":"","o_tlc_agency_service":"
# ...
